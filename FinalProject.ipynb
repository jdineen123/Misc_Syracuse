# %% [markdown]
# ## Load Packages

# %%
# %config IPCompleter.greedy=True #tabbing for autocomplete
# !pip install face_recognition
# !pip install opencv-python
import face_recognition
import cv2
# !pip install dlib
import scipy.misc
import imageio
# !pip install pillow
# !pip install scipy
import sys
# !pip install numba
from numba import vectorize

# %% [markdown]
# ## Detecting Face + Landmarks, Test

# %%
image = face_recognition.load_image_file("data/obama.jpg")
face_locations = face_recognition.face_locations(image, model="cnn")

image = face_recognition.load_image_file("data/obama.jpg")
face_landmarks_list = face_recognition.face_landmarks(image)
# Out:
# [(156, 1100, 401, 856)]

# %% [markdown]
# ### Roster of active students

# %% [markdown]
# Roster:
# Jon Fox
# Jewell Anderson  *
# Stephanie Chavers *
# Kyle Fox *
# Ekow Fynn *
# Michael King *
# Martha Love *
# Amara Moosa *
# Josh Olson *
# Vincent Toney *
# Michael Wangerin *
# Jacob Dineen *

# %% [markdown]
# ### Using MP4 rendering

# %%
# Open the input movie file
input_movie = cv2.VideoCapture("Test.mp4")

length = int(input_movie.get(cv2.CAP_PROP_FRAME_COUNT))

# Create an output movie file (make sure resolution/frame rate matches input video!)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
output_movie = cv2.VideoWriter('TestOutput2.avi', fourcc, 30.25, (1920, 1048))

# Load some sample pictures and learn how to recognize them.
##SET 1
AmaraMoosa_image = face_recognition.load_image_file("FacialRec_TrainingData/Amara-Moosa.PNG")
AmaraMoosa_image_face_encoding = face_recognition.face_encodings(AmaraMoosa_image)[0]

EkowFynn_image = face_recognition.load_image_file("FacialRec_TrainingData/Ekow-Fynn.PNG")
EkowFynn_image_face_encoding = face_recognition.face_encodings(EkowFynn_image)[0]

JacobDineen_image = face_recognition.load_image_file("FacialRec_TrainingData/jacob-dineen.PNG")
JacobDineen_image_encoding = face_recognition.face_encodings(JacobDineen_image)[0]

JewellAnderson_image = face_recognition.load_image_file("FacialRec_TrainingData/Jewell-Anderson.PNG")
JewellAnderson_image_face_encoding = face_recognition.face_encodings(JewellAnderson_image)[0]

JoshOlson_image = face_recognition.load_image_file("FacialRec_TrainingData/Josh-Olson.PNG")
JoshOlson_image_face_encoding = face_recognition.face_encodings(JoshOlson_image)[0]

KyleFox_image = face_recognition.load_image_file("FacialRec_TrainingData/Kyle-Fox.PNG")
KyleFox_image_face_encoding = face_recognition.face_encodings(KyleFox_image)[0]

MarthaLove_image = face_recognition.load_image_file("FacialRec_TrainingData/Martha-Love.PNG")
MarthaLove_image_face_encoding = face_recognition.face_encodings(MarthaLove_image)[0]

MichaelWangerin_image = face_recognition.load_image_file("FacialRec_TrainingData/Michael-Wangerin.PNG")
MichaelWangerin_image_face_encoding = face_recognition.face_encodings(MichaelWangerin_image)[0]

MichaelKing_image = face_recognition.load_image_file("FacialRec_TrainingData/Michael-King.PNG")
MichaelKing_image_face_encoding = face_recognition.face_encodings(MichaelKing_image)[0]

StephanieChavers_image = face_recognition.load_image_file("FacialRec_TrainingData/Stephanie-Chavers.PNG")
StephanieChavers_image_face_encoding = face_recognition.face_encodings(StephanieChavers_image)[0]

VincentToney_image = face_recognition.load_image_file("FacialRec_TrainingData/Vincent-Toney.PNG")
VincentToney_image_face_encoding = face_recognition.face_encodings(VincentToney_image)[0]
                 
##SET 2
AmaraMoosa_image1 = face_recognition.load_image_file("FacialRec_TrainingData/Amara-Moosa1.PNG")
AmaraMoosa_image_face_encoding1 = face_recognition.face_encodings(AmaraMoosa_image1)[0]

JacobDineen_image1 = face_recognition.load_image_file("FacialRec_TrainingData/jacob-dineen1.PNG")
JacobDineen_image_encoding1 = face_recognition.face_encodings(JacobDineen_image1)[0]

JewellAnderson_image1 = face_recognition.load_image_file("FacialRec_TrainingData/Jewell-Anderson1.PNG")
JewellAnderson_image_face_encoding1 = face_recognition.face_encodings(JewellAnderson_image1)[0]

JoshOlson_image1 = face_recognition.load_image_file("FacialRec_TrainingData/Josh-Olson1.PNG")
JoshOlson_image_face_encoding1 = face_recognition.face_encodings(JoshOlson_image1)[0]

KyleFox_image1 = face_recognition.load_image_file("FacialRec_TrainingData/Kyle-Fox1.PNG")
KyleFox_image_face_encoding1 = face_recognition.face_encodings(KyleFox_image1)[0]

MarthaLove_image1 = face_recognition.load_image_file("FacialRec_TrainingData/Martha-Love1.PNG")
MarthaLove_image_face_encoding1 = face_recognition.face_encodings(MarthaLove_image1)[0]

MichaelWangerin_image1 = face_recognition.load_image_file("FacialRec_TrainingData/Michael-Wangerin1.PNG")
MichaelWangerin_image_face_encoding1 = face_recognition.face_encodings(MichaelWangerin_image1)[0]


StephanieChavers_image1 = face_recognition.load_image_file("FacialRec_TrainingData/Stephanie-Chavers1.PNG")
StephanieChavers_image_face_encoding1 = face_recognition.face_encodings(StephanieChavers_image1)[0]

VincentToney_image1 = face_recognition.load_image_file("FacialRec_TrainingData/Vincent-Toney1.PNG")
VincentToney_image_face_encoding1 = face_recognition.face_encodings(VincentToney_image1)[0]                                            




known_faces = [    
    AmaraMoosa_image_face_encoding, #1
    EkowFynn_image_face_encoding, #2
    JacobDineen_image_encoding, #3
    JewellAnderson_image_face_encoding, #4
    JoshOlson_image_face_encoding, #5
    KyleFox_image_face_encoding, #6
    MarthaLove_image_face_encoding, #7 
    MichaelWangerin_image_face_encoding, #8
    MichaelKing_image_face_encoding, #9
    StephanieChavers_image_face_encoding, #10
    VincentToney_image_face_encoding, #11
    AmaraMoosa_image_face_encoding1, #12
    JacobDineen_image_encoding1, #13
    JewellAnderson_image_face_encoding1, #14
    JoshOlson_image_face_encoding1, #15
    KyleFox_image_face_encoding1, #16
    MarthaLove_image_face_encoding1, #17
    MichaelWangerin_image_face_encoding1, #18
    StephanieChavers_image_face_encoding1, #19
    VincentToney_image_face_encoding1 #20
]

# Initialize some variables
face_locations = []
face_encodings = []
face_names = []
frame_number = 0

while True:
    # Grab a single frame of video
    ret, frame = input_movie.read()
    frame_number += 1

    # Quit when the input video file ends
    if not ret:
        break

 # Convert the image from BGR color (which OpenCV uses) to RGB color (which face_recognition uses)
    rgb_frame = frame[:, :, ::-1]

    # Find all the faces and face encodings in the current frame of video
    face_locations = face_recognition.face_locations(rgb_frame)
    face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)

    face_names = []
    for face_encoding in face_encodings:
        # See if the face is a match for the known face(s)
        match = face_recognition.compare_faces(known_faces, face_encoding, tolerance=0.50)

        # If you had more than 2 faces, you could make this logic a lot prettier
        # but I kept it simple for the demo
        name = None
        if match[0]:
            name = "Amara Moosa"
        elif match[1]:
            name = "Ekow Fynn"
        elif match[2]:
            name = "Jacob Dineen"
        elif match[3]:
            name = "Jewell Anderson"
        elif match[4]:
            name = "Josh Olson"
        elif match[5]:
            name = "Kyle Fox"
        elif match[6]:
            name = "Martha Love"
        elif match[7]:
            name = "Michael King"
        elif match[8]:
            name = "Michael Wangerin"
        elif match[9]:
            name = "Stephanie Chavers"
        elif match[10]:
            name = "Vincent Toney"
        elif match[11]:
            name = "Amara Moosa"  
        elif match[12]:
            name = "Jacob Dineen"  
        elif match[13]:
            name = "Jewell Anderson"           
        elif match[14]:
            name = "Josh Olson"
        elif match[15]:
            name = "Kyle Fox"
        elif match[16]:
            name = "Martha Love"
        elif match[17]:
            name = "Michael Wangerin"       
        elif match[18]:
            name = "Stephanie Chavers"                  
        elif match[18]:
            name = "Stephanie Chavers"     
        elif match[19]:
            name = "Vincent Toney"              
            
        face_names.append(name)

    # Label the results
    for (top, right, bottom, left), name in zip(face_locations, face_names):
        if not name:
            continue

        # Draw a box around the face
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

        # Draw a label with a name below the face
        cv2.rectangle(frame, (left, bottom - 25), (right, bottom), (0, 0, 255), cv2.FILLED)
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(frame, name, (left + 6, bottom - 6), font, 0.5, (255, 255, 255), 1)

    # Write the resulting image to the output video file
    print("Writing frame {} / {}".format(frame_number, length))
    output_movie.write(frame)

# All done!
input_movie.release()
cv2.destroyAllWindows()
# Out:
# Writing frame 1 / 430
# Writing frame 2 / 430
# Writing frame 3 / 430
# Writing frame 4 / 430
# Writing frame 5 / 430
# Writing frame 6 / 430
# Writing frame 7 / 430
# Writing frame 8 / 430
# Writing frame 9 / 430
# Writing frame 10 / 430
# Writing frame 11 / 430
# Writing frame 12 / 430
# Writing frame 13 / 430
# Writing frame 14 / 430
# Writing frame 15 / 430
# Writing frame 16 / 430
# Writing frame 17 / 430
# Writing frame 18 / 430
# Writing frame 19 / 430
# Writing frame 20 / 430
# Writing frame 21 / 430
# Writing frame 22 / 430
# Writing frame 23 / 430
# Writing frame 24 / 430
# Writing frame 25 / 430
# Writing frame 26 / 430
# Writing frame 27 / 430
# Writing frame 28 / 430
# Writing frame 29 / 430
# Writing frame 30 / 430
# Writing frame 31 / 430
# Writing frame 32 / 430
# Writing frame 33 / 430
# Writing frame 34 / 430
# Writing frame 35 / 430
# Writing frame 36 / 430
# Writing frame 37 / 430
# Writing frame 38 / 430
# Writing frame 39 / 430
# Writing frame 40 / 430
# ...

# %%
import face_recognition
import cv2

# This is a demo of running face recognition on live video from your webcam. It's a little more complicated than the
# other example, but it includes some basic performance tweaks to make things run a lot faster:
#   1. Process each video frame at 1/4 resolution (though still display it at full resolution)
#   2. Only detect faces in every other frame of video.

# PLEASE NOTE: This example requires OpenCV (the `cv2` library) to be installed only to read from your webcam.
# OpenCV is *not* required to use the face_recognition library. It's only required if you want to run this
# specific demo. If you have trouble installing it, try any of the other demos that don't require it instead.

# Get a reference to webcam #0 (the default one)
video_capture = cv2.VideoCapture(0)



# Create arrays of known face encodings and their names
known_face_encodings = [    
    AmaraMoosa_image_face_encoding, #1
    EkowFynn_image_face_encoding, #2
    JacobDineen_image_encoding, #3
    JewellAnderson_image_face_encoding, #4
    JoshOlson_image_face_encoding, #5
    KyleFox_image_face_encoding, #6
    MarthaLove_image_face_encoding, #7 
    MichaelWangerin_image_face_encoding, #8
    MichaelKing_image_face_encoding, #9
    StephanieChavers_image_face_encoding, #10
    VincentToney_image_face_encoding, #11
    AmaraMoosa_image_face_encoding1, #12
    JacobDineen_image_encoding1, #13
    JewellAnderson_image_face_encoding1, #14
    JoshOlson_image_face_encoding1, #15
    KyleFox_image_face_encoding1, #16
    MarthaLove_image_face_encoding1, #17
    MichaelWangerin_image_face_encoding1, #18
    StephanieChavers_image_face_encoding1, #19
    VincentToney_image_face_encoding1 #20
]
known_face_names = [
    "Amara Moosa",
    "Ekow Fynn",
    "Jacob Dineen",
    "Jewell Anderson",
    "Josh Olson",
    "Kyle Fox",
    "Martha Love",
    "Michael Wangerin",
    "Michael King",
    "Stephanie Chavers",
    "Vincent Toney"    
]

# Initialize some variables
face_locations = []
face_encodings = []
face_names = []
process_this_frame = True

while True:
    # Grab a single frame of video
    ret, frame = video_capture.read()

    # Resize frame of video to 1/4 size for faster face recognition processing
    small_frame = cv2.resize(frame, (0, 0), fx=1, fy=1)

    # Convert the image from BGR color (which OpenCV uses) to RGB color (which face_recognition uses)
    rgb_small_frame = small_frame[:, :, ::-1]

    # Only process every other frame of video to save time
    if process_this_frame:
        # Find all the faces and face encodings in the current frame of video
        face_locations = face_recognition.face_locations(rgb_small_frame)
        face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)

        face_names = []
        for face_encoding in face_encodings:
            # See if the face is a match for the known face(s)
            matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
            name = "Unknown"

            # If a match was found in known_face_encodings, just use the first one.
            if True in matches:
                first_match_index = matches.index(True)
                name = known_face_names[first_match_index]

            face_names.append(name)

    process_this_frame = not process_this_frame


    # Display the results
    for (top, right, bottom, left), name in zip(face_locations, face_names):
        # Scale back up face locations since the frame we detected in was scaled to 1/4 size
        top *= 4
        right *= 4
        bottom *= 4
        left *= 4

        # Draw a box around the face
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

        # Draw a label with a name below the face
        cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

    # Display the resulting image
    cv2.imshow('Video', frame)

    # Hit 'q' on the keyboard to quit!
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release handle to the webcam
video_capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-df3834f9b335> in <module>()
#      18 # Create arrays of known face encodings and their names
#      19 known_face_encodings = [
# ---> 20     AmaraMoosa_image_face_encoding, #1
#      21     EkowFynn_image_face_encoding, #2
#      22     JacobDineen_image_encoding, #3
#
# NameError: name 'AmaraMoosa_image_face_encoding' is not defined
